# %% [markdown]
# <a href="https://colab.research.google.com/github/cookmo/Cook_NEUR265/blob/main/coding_homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Morgan Cook
# *NEUR265: Introduction to Neural Data Analysis*
#
# **February 19, 2026**

# %%
# Importing programs (#2)
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Importing data sets as numpy arrays (#3)
url1 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
url2 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'

v_rest_sst = np.loadtxt(url1)
v_rest_pvalb = np.loadtxt(url2)

# %%
# Finding means of data (#4a)
mean_sst = np.mean(v_rest_sst)
mean_pvalb = np.mean(v_rest_pvalb)
print(p_value)

# Performing a t-test for data means (#4b)
t_stat, p_value = stats.ttest_ind(v_rest_sst, v_rest_pvalb)

# Plotting histograms and labeling axes (#4c, #4d)
if p_value < 0.05:
  fig, ax = plt.subplots(1,2, figsize=(10,4))

  ax[0].hist(v_rest_sst)
  ax[0].set_xlabel('Resting Membrane Potential (mV)')
  ax[0].set_ylabel('Frequency')
  ax[0].set_title('SST')

  ax[1].hist(v_rest_pvalb)
  ax[1].set_xlabel('Resting Membrane Potential (mV)')
  ax[1].set_ylabel('Frequency')
  ax[1].set_title('Pvalb')
# Out:
# 7.159828660199036e-09

# %%
# Defining the function vrestHist (#5)
def vrestHist():
  mean_sst = np.mean(v_rest_sst)
  mean_pvalb = np.mean(v_rest_pvalb)

  t_stat, p_value = stats.ttest_ind(v_rest_sst, v_rest_pvalb)

  if p_value < 0.05:
    fig, ax = plt.subplots(1,2, figsize=(10,4))

    ax[0].hist(v_rest_sst)
    ax[0].set_xlabel('Resting Membrane Potential (mV)')
    ax[0].set_ylabel('Frequency')
    ax[0].set_title('SST')

    ax[1].hist(v_rest_pvalb)
    ax[1].set_xlabel('Resting Membrane Potential (mV)')
    ax[1].set_ylabel('Frequency')
    ax[1].set_title('Pvalb')

# %%
# Calling the function defined in step 5 (#6)
vrestHist()

# %%
# Creating loop and scatter plot with value parameters (#7a, #7b, #7c)
plt.figure()

for i in range(len(v_rest_sst)):
  x = v_rest_sst[i]
  y = v_rest_pvalb[i]

  if x > -60 and y > -60:
    plt.scatter(x, y, color='red')
  elif x > -60 and y < -60:
    plt.scatter(x, y, color='green')
  elif x < -60 and y < -60:
    plt.scatter(x, y, color='blue')
  elif x < -60 and y > -60:
    plt.scatter(x, y, color='purple')

# Labeling plot axes (#7d)
plt.xlabel('SST Resting Membrane Potential')
plt.ylabel('Pvalb Resting Membrane Potential')
# Out:
# Text(0, 0.5, 'Pvalb Resting Membrane Potential')

# %%
# Defining the function vrestScatter (#8)
def vrestScatter():
  plt.figure()

  for i in range(len(v_rest_sst)):
    x = v_rest_sst[i]
    y = v_rest_pvalb[i]

    if x > -60 and y > -60:
      plt.scatter(x, y, color='red')
    elif x > -60 and y < -60:
      plt.scatter(x, y, color='green')
    elif x < -60 and y < -60:
      plt.scatter(x, y, color='blue')
    elif x < -60 and y > -60:
      plt.scatter(x, y, color='purple')

  plt.xlabel('SST Resting Membrane Potential')
  plt.ylabel('Pvalb Resting Membrane Potential')

# %%
# Calling the function defined in step 8 to ensure that the code runs
vrestScatter()
